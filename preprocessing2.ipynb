# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mp
import numpy as np

# %%
df= pd.read_csv("laptops.csv")
df
# Out:
#                                                  title   price
# 0    HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...  39,990  \
# 1    Dell Vostro 3420 Laptop,12th Gen Intel Core i3...  41,990
# 2    Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...  44,490
# 3    HP 255 G8 Laptop with AMD Athlon Silver 3050U ...  26,999
# 4    Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...  33,639
# ..                                                 ...     ...
# 334  Dell Inspiron 3525 Laptop, AMD Ryzen R3-5425U,...  39,990
# 335  (Renewed) DELL Latitude 5490 Core i5 8th Gen L...  26,615
# 336  ASUS Vivobook S 14 Flip (2023), AMD Ryzen 5 75...  68,990
# 337  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...  64,999
# 338  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...  56,990
#
#                  rating
# 0                   NaN
# 1                   NaN
# 2    4.4 out of 5 stars
# 3                   NaN
# 4                   NaN
# ..                  ...
# 334                 NaN
# 335                 NaN
# 336                 NaN
# 337                 NaN
# 338                 NaN
#
# [339 rows x 3 columns]

# %%
df.head()
# Out:
#                                                title   price
# 0  HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...  39,990  \
# 1  Dell Vostro 3420 Laptop,12th Gen Intel Core i3...  41,990
# 2  Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...  44,490
# 3  HP 255 G8 Laptop with AMD Athlon Silver 3050U ...  26,999
# 4  Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...  33,639
#
#                rating
# 0                 NaN
# 1                 NaN
# 2  4.4 out of 5 stars
# 3                 NaN
# 4                 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   339 non-null    object
#  1   price   331 non-null    object
#  2   rating  24 non-null     object
# dtypes: object(3)
# memory usage: 8.1+ KB

# %%
print(df.columns.to_list())
# Out:
# ['title', 'price', 'rating']

# %%
def clean_price_column(price):
    if isinstance (price,str):
         price= price.replace(',','')
         price=price.strip()
         if price.isnumeric():
             price= int(price)
             return price
         if len(price)==0:
              return np.nan
    return price

# %%
clean_price_column('1,999')
# Out:
# 1999

# %%
df['cleaned_price']= df['price'].apply(clean_price_column)
df
# Out:
#                                                  title   price
# 0    HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...  39,990  \
# 1    Dell Vostro 3420 Laptop,12th Gen Intel Core i3...  41,990
# 2    Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...  44,490
# 3    HP 255 G8 Laptop with AMD Athlon Silver 3050U ...  26,999
# 4    Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...  33,639
# ..                                                 ...     ...
# 334  Dell Inspiron 3525 Laptop, AMD Ryzen R3-5425U,...  39,990
# 335  (Renewed) DELL Latitude 5490 Core i5 8th Gen L...  26,615
# 336  ASUS Vivobook S 14 Flip (2023), AMD Ryzen 5 75...  68,990
# 337  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...  64,999
# 338  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...  56,990
#
#                  rating  cleaned_price
# 0                   NaN        39990.0
# 1                   NaN        41990.0
# 2    4.4 out of 5 stars        44490.0
# 3                   NaN        26999.0
# 4                   NaN        33639.0
# ..                  ...            ...
# 334                 NaN        39990.0
# 335                 NaN        26615.0
# 336                 NaN        68990.0
# 337                 NaN        64999.0
# 338                 NaN        56990.0
#
# [339 rows x 4 columns]

# %%
def clean_rating_column(rating):
    if isinstance(rating,str):
        rating= rating.split()[0]
        return float(rating)
    return rating

# %%
df['cleaned_rating']=df['rating'].apply(clean_rating_column)
df
# Out:
#                                                  title   price
# 0    HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...  39,990  \
# 1    Dell Vostro 3420 Laptop,12th Gen Intel Core i3...  41,990
# 2    Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...  44,490
# 3    HP 255 G8 Laptop with AMD Athlon Silver 3050U ...  26,999
# 4    Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...  33,639
# ..                                                 ...     ...
# 334  Dell Inspiron 3525 Laptop, AMD Ryzen R3-5425U,...  39,990
# 335  (Renewed) DELL Latitude 5490 Core i5 8th Gen L...  26,615
# 336  ASUS Vivobook S 14 Flip (2023), AMD Ryzen 5 75...  68,990
# 337  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...  64,999
# 338  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...  56,990
#
#                  rating  cleaned_price  cleaned_rating
# 0                   NaN        39990.0             NaN
# 1                   NaN        41990.0             NaN
# 2    4.4 out of 5 stars        44490.0             4.4
# 3                   NaN        26999.0             NaN
# 4                   NaN        33639.0             NaN
# ..                  ...            ...             ...
# 334                 NaN        39990.0             NaN
# 335                 NaN        26615.0             NaN
# 336                 NaN        68990.0             NaN
# 337                 NaN        64999.0             NaN
# 338                 NaN        56990.0             NaN
#
# [339 rows x 5 columns]

# %%
df.sort_values(by='cleaned_price',ascending=False,inplace=True)
df
# Out:
#                                                  title  cleaned_price
# 267  MSI Raider GE78HX, Intel 13th Gen. i9-13980HX,...       499990.0  \
# 42   Dell XPS 9720 Laptop, Intel i9-12900HK, 32GB D...       385578.0
# 175  ASUS ROG Zephyrus Duo 16 (2023) Dual Screen La...       379990.0
# 22   Apple 2023 MacBook Pro Laptop M2 Max chip with...       349900.0
# 220  Apple 2023 MacBook Pro Laptop M2 Max chip with...       349900.0
# ..                                                 ...            ...
# 191  (renewed) Latitude D620 core 2 Duo Laptop/4 gb...            NaN
# 239  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...            NaN
# 276  (Renewed) Lenovo IdeaPad 3 11th Gen Intel Core...            NaN
# 301  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...            NaN
# 314  (Renewed) Dell Latitude Laptop E5470 Intel Cor...            NaN
#
#      cleaned_rating
# 267             NaN
# 42              NaN
# 175             NaN
# 22              NaN
# 220             NaN
# ..              ...
# 191             NaN
# 239             NaN
# 276             NaN
# 301             NaN
# 314             NaN
#
# [339 rows x 3 columns]

# %%
df.drop(columns=['price','rating'], inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.drop(columns=['price','rating'], inplace=True)
#       2 df
#
# File c:\Users\tabas\miniconda3\lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# File c:\Users\tabas\miniconda3\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\Users\tabas\miniconda3\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\Users\tabas\miniconda3\lib\site-packages\pandas\core\indexes\base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['price', 'rating'] not found in axis"
