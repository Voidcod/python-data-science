# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(df, x='sepal_width',bins=15,kde=True) # kernel density estimation plot
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
fig,ax=plt.subplots(figsize=(8,4))
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax,color="red")
plt.savefig('histogram.png',dpi=300)

# %%
sns.color_palette('rainbow')
# Out:
# [(0.21764705882352942, 0.42912060877260894, 0.9755119679804366),
#  (0.0725490196078431, 0.7829276104921027, 0.9005867023006374),
#  (0.3549019607843137, 0.9741386021045101, 0.7829276104921028),
#  (0.6450980392156862, 0.9741386021045102, 0.622112816721474),
#  (0.9274509803921569, 0.7829276104921029, 0.43467642176596505),
#  (1.0, 0.42912060877260916, 0.2199463578396687)]

# %%
sns.set_palette('rainbow')
fig,ax=plt.subplots(figsize=(20,5),ncols=4)
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[0],color="red")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[1],color="blue")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[2],color="green")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[3],color="yellow")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.set_palette('rainbow')
fig,ax=plt.subplots(figsize=(40,40),nrows=4)
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[0],color="red")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[1],color="blue")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[2],color="green")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[3],color="yellow")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.set_palette('rainbow')
fig,ax=plt.subplots(figsize=(40,40),nrows=4)
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[0],color="red")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[1],color="blue")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[2],color="green")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[3],color="yellow")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.set_palette('rainbow')
fig,ax=plt.subplots(figsize=(20,20),ncols=2,nrows=2)
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[0,0],color="red")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[0,1],color="blue")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[1,0],color="green")
sns.histplot(df,x='sepal_length',bins=15,kde=True,ax=ax[1,1],color="yellow")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>
